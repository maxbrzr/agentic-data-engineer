# %%
from dcat_ap_hub import Dataset

url = "http://data.sdil.de/en/dataset/10-5281-zenodo-11469702"

ds = Dataset.from_url(url)
files = ds.download(data_dir="./data")
# Out:
# 2026-07-29 14:44:18,485 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_3.csv
# tcm5_dataset_3.txt: 10.3MB [00:00, 12.1MB/s]
# 2026-07-29 14:44:19,604 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_4.csv
# tcm5_dataset_4.txt: 10.3MB [00:01, 9.79MB/s]
# 2026-07-29 14:44:20,894 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_1.csv
# tcm5_dataset_1.txt: 10.4MB [00:01, 9.96MB/s]
# 2026-07-29 14:44:22,095 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_2.csv
# tcm5_dataset_2.txt: 10.3MB [00:00, 10.5MB/s]
# 2026-07-29 14:44:23,245 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_6.csv
# tcm5_dataset_6.txt: 10.3MB [00:01, 9.71MB/s]
# 2026-07-29 14:44:24,515 - dcat-ap-hub - INFO - Downloading: tcm5_dataset_5.csv
# tcm5_dataset_5.txt: 10.3MB [00:00, 10.9MB/s]
# Saving metadata for offline usage...
