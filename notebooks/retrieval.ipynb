# %%
from dcat_ap_hub import Dataset

url = "https://data.hammerhai.eu/en/dataset/2256130"

ds = Dataset.from_url(url)
files = ds.download(data_dir="./data")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 from dcat_ap_hub import Dataset
#       2
#       3 url = "https://data.hammerhai.eu/en/dataset/2256130"
#       4
# ----> 5 ds = Dataset.from_url(url)
#       6 files = ds.download(data_dir="./data")
#
# File ~/Teco/argentic_data_engineer/agentic-data-engineer/.venv/lib/python3.12/site-packages/dcat_ap_hub/core/dataset.py:72, in Dataset.from_url(cls, url, verbose)
#      70 @classmethod
#      71 def from_url(cls, url: str, verbose: bool = False) -> Dataset:
# ---> 72     meta = fetch_and_parse(url, verbose=verbose)
#      73     return cls(meta)
#
# File ~/Teco/argentic_data_engineer/agentic-data-engineer/.venv/lib/python3.12/site-packages/dcat_ap_hub/internals/parser.py:145, in fetch_and_parse(url, verbose)
#     143     logger.info(f"Fetching: {url}")
# ...
